# %% [markdown]
# ## Federated Learning to Predict Hospital Admissions
# ### Section 2: Single Data Source, Decision Tree
# The second script trains a decision on circulatory provider's data
#
# This notebook is meant to signal the current method of training models using a single
# centralized data source.  Our results here will be compared to a decision tree trained using federated learning combining multiple data sources
#
# I use the ID3 implementation found here: https://github.com/svaante/decision-tree-id3

# %%
import pandas as pd
import numpy as np
from id3 import Id3Estimator
from id3 import export_graphviz, export_text
from sklearn.metrics import accuracy_score, classification_report
from sklearn import tree
import pickle

# %%
# depth range
max_depth = 6

# %%
provider_train = pd.read_csv('./Party3/Provider_train.csv')
provider_test = pd.read_csv('./Party3/Provider_test.csv')

display(provider_train.head())
display(provider_test.head())
# Out:
#               race  gender      age  admission_type_id  \
# 0         Hispanic  Female  [70-80)                  3
# 1        Caucasian  Female  [70-80)                  5
# 2        Caucasian    Male  [60-70)                  1
# 3  AfricanAmerican    Male  [70-80)                  1
# 4        Caucasian  Female  [70-80)                  3
#
#    discharge_disposition_id  admission_source_id time_in_hospital  \
# 0                         5                    1   (1.096, 1.499]
# 1                         6                   17   (1.096, 1.499]
# 2                         1                    7   (1.096, 1.499]
# 3                         3                    7   (1.902, 2.305]
# 4                         1                    1    (-inf, 1.096]
#
#   num_lab_procedures  num_procedures num_medications  ... citoglipton insulin  \
# 0       (53.4, 79.6]   (-inf, 0.389]  (2.179, 2.921]  ...          No  Steady
# 1       (-inf, 27.2]   (-inf, 0.389]  (2.921, 3.664]  ...          No      Up
# 2       (-inf, 27.2]  (1.168, 1.557]  (2.179, 2.921]  ...          No      No
# 3       (27.2, 53.4]  (0.389, 0.778]  (2.921, 3.664]  ...          No      Up
# 4       (-inf, 27.2]    (1.557, inf]  (2.179, 2.921]  ...          No    Down
#
#   glyburide-metformin glipizide-metformin glimepiride-pioglitazone  \
# 0                  No                  No                       No
# 1                  No                  No                       No
# 2                  No                  No                       No
# 3                  No                  No                       No
# 4                  No                  No                       No
#
#   metformin-rosiglitazone metformin-pioglitazone change diabetesMed class
# 0                      No                     No     No         Yes   <30
# 1                      No                     No     Ch         Yes   <30
# 2                      No                     No     No         Yes   <30
# 3                      No                     No     Ch         Yes   <30
# 4                      No                     No     Ch         Yes   <30
#
# [5 rows x 43 columns]
#               race  gender      age  admission_type_id  \
# 0  AfricanAmerican  Female  [70-80)                  3
# 1  AfricanAmerican    Male  [40-50)                  1
# 2            Other    Male  [60-70)                  1
# 3        Caucasian    Male  [50-60)                  1
# 4  AfricanAmerican    Male  [60-70)                  1
#
#    discharge_disposition_id  admission_source_id time_in_hospital  \
# 0                         1                    1   (1.096, 1.499]
# 1                         3                    7   (1.902, 2.305]
# 2                         2                    7   (1.902, 2.305]
# 3                         1                    7    (-inf, 1.096]
# 4                         1                    7   (1.902, 2.305]
#
#   num_lab_procedures  num_procedures num_medications  ... citoglipton insulin  \
# 0       (-inf, 27.2]  (0.778, 1.168]   (-inf, 1.436]  ...          No      No
# 1       (53.4, 79.6]  (0.389, 0.778]  (2.179, 2.921]  ...          No      No
# 2      (79.6, 105.8]    (1.557, inf]  (2.921, 3.664]  ...          No    Down
# 3       (27.2, 53.4]   (-inf, 0.389]  (2.179, 2.921]  ...          No  Steady
# 4       (53.4, 79.6]    (1.557, inf]  (2.921, 3.664]  ...          No    Down
#
#   glyburide-metformin glipizide-metformin glimepiride-pioglitazone  \
# 0                  No                  No                       No
# 1                  No                  No                       No
# 2                  No                  No                       No
# 3                  No                  No                       No
# 4                  No                  No                       No
#
#   metformin-rosiglitazone metformin-pioglitazone change diabetesMed class
# 0                      No                     No     No          No    NO
# 1                      No                     No     No          No    NO
# 2                      No                     No     Ch         Yes   <30
# 3                      No                     No     Ch         Yes    NO
# 4                      No                     No     Ch         Yes   >30
#
# [5 rows x 43 columns]

# %%
# convert to standard sklearn format
X_train, y_train = provider_train.drop(columns = ['class']), provider_train['class']
X_test, y_test = provider_test.drop(columns = ['class']), provider_test['class']

# convert to numpy format for estimator
provider_X_train = X_train.applymap(str)
features = X_train.columns
provider_y_train = y_train.values
provider_X_train = X_train.values.astype('<U30')

X_test = X_test.applymap(str)
X_test = X_test.values.astype('<U30')
y_test = y_test.values

# %%
# Train decision tree at certain depth
# saves model in text format
def run_id3(depth):
    model = Id3Estimator(max_depth=depth)
    model.fit(provider_X_train, provider_y_train, check_input = False)
    
    # Save Model
    tree = export_text(model.tree_, feature_names = provider_test.columns)
    with open(f'Models/Base DT_{depth}.txt', 'w') as f:
        f.writelines(tree)
        
    return model

# %%
# evaluate results on training data
import warnings
warnings.filterwarnings("ignore")

for i in range(1, max_depth + 1):
    print(f'... Running ID3 with depth {i}...')
    model = run_id3(i)

    # Accuracy on Training dataset
    preds = model.predict(provider_X_train)
    print(f"Accuracy at depth {i}: ", str(round(accuracy_score(provider_y_train, preds),2)))
    print(classification_report(provider_y_train, preds))
    print("\n")
# Out:
# ... Running ID3 with depth 1...
# Accuracy at depth 1:  0.39
#               precision    recall  f1-score   support
#
#          <30       0.50      0.25      0.33      1669
#          >30       0.38      0.20      0.26      1669
#           NO       0.37      0.74      0.50      1669
#
#    micro avg       0.39      0.39      0.39      5007
#    macro avg       0.42      0.39      0.36      5007
# weighted avg       0.42      0.39      0.36      5007
#
#
#
# ... Running ID3 with depth 2...
# Accuracy at depth 2:  0.44
#               precision    recall  f1-score   support
#
#          <30       0.47      0.43      0.45      1669
#          >30       0.41      0.27      0.33      1669
#           NO       0.44      0.61      0.51      1669
#
#    micro avg       0.44      0.44      0.44      5007
#    macro avg       0.44      0.44      0.43      5007
# weighted avg       0.44      0.44      0.43      5007
#
#
#
# ... Running ID3 with depth 3...
# Accuracy at depth 3:  0.48
#               precision    recall  f1-score   support
#
#          <30       0.53      0.42      0.47      1669
#          >30       0.47      0.33      0.39      1669
#           NO       0.46      0.69      0.55      1669
#
#    micro avg       0.48      0.48      0.48      5007
#    macro avg       0.49      0.48      0.47      5007
# weighted avg       0.49      0.48      0.47      5007
#
#
#
# ... Running ID3 with depth 4...
# Accuracy at depth 4:  0.54
#               precision    recall  f1-score   support
#
#          <30       0.58      0.54      0.56      1669
#          >30       0.51      0.52      0.51      1669
#           NO       0.55      0.57      0.56      1669
#
#    micro avg       0.54      0.54      0.54      5007
#    macro avg       0.54      0.54      0.54      5007
# weighted avg       0.54      0.54      0.54      5007
#
#
#
# ... Running ID3 with depth 5...
# Accuracy at depth 5:  0.63
#               precision    recall  f1-score   support
#
#          <30       0.68      0.60      0.64      1669
#          >30       0.57      0.67      0.62      1669
#           NO       0.66      0.60      0.63      1669
#
#    micro avg       0.63      0.63      0.63      5007
#    macro avg       0.63      0.63      0.63      5007
# weighted avg       0.63      0.63      0.63      5007
#
#
#
# ... Running ID3 with depth 6...
# Accuracy at depth 6:  0.72
#               precision    recall  f1-score   support
#
#          <30       0.78      0.69      0.73      1669
#          >30       0.66      0.77      0.71      1669
#           NO       0.73      0.68      0.71      1669
#
#    micro avg       0.72      0.72      0.72      5007
#    macro avg       0.72      0.72      0.72      5007
# weighted avg       0.72      0.72      0.72      5007
